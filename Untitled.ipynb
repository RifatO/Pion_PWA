# %% [markdown]
# # Pion PWA - interpolacija podataka
# ## Prikaz rezultata interpolacije - usporedba sa originalnim podacima
# ## crvena - interpolirani podaci
# ## plava - originalni podaci

# %%
from IPython.display import Image
Image("E_obs/E.png")
